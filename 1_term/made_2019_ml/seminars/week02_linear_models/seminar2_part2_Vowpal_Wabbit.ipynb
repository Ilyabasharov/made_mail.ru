# %% [markdown]
# ![title](vw.png)

# %% [markdown]
# https://github.com/VowpalWabbit/vowpal_wabbit

# %% [markdown]
# webspam: https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary.html

# %% [markdown]
# Реализация стохастического градиентного спуска для линейхных моделей, позволяющая запускаться на больших объёмах данных, за счет последовательной загрузки и обработки примеров.

# %% [markdown]
# Основной интерфейс работы -- shell

# %%
# !python phraug/split.py webspam_wc_normalized_trigram.svm \
train_v.txt test_v.txt 0.8 dat_seed
# Out:
# P = 0.8
# 100000
# 200000
# 300000

# %% [markdown]
# ### Формат входных данных

# %% [markdown]
# [Label] [Importance] [Tag]|Namespace Features |Namespace Features ... |Namespace Features

# %% [markdown]
# Namespace=String[:Value]
#
# Features=(String[:Value] )*
#
# где [] обозначает необязательные элементы, а (...)* означает повтор неопределенное число раз.
#
#     Label - целевая переменная
#     Importance - вес объекта
#     Tag - является некоторой строкой без пробелов и отвечает за некоторое "название" примера, которое сохраняется при предсказании ответа
#     Namespace - служит для группировки признаков. При использваонии в аргументах, Namespace именуются по первой букве
#     Features - признаками объекта. Если признаком является строка, то она хешируется. Значение признака по умолчанию - 1, но его можно переопределить добавив значение после :. Все признаки не входящие в данную строку считаются равными 0.

# %% [markdown]
# Для приведения данных к необходимому виду, нужно либо создать отдельный файл, либо можем сразу писать в stdin

# %% [markdown]
# -b 29 – используем 29 бит для хэширования, то есть признаковое пространство ограничено признаками 2^29

# %% [markdown]
# --cache_file создаем на бинарный файл сразу из входных данных, что бы потом использовать при обучении

# %%
# !python phraug/libsvm2vw.py train_v.txt /dev/stdout \
| vw -b 29 --cache_file train_v.cache
# Out:
# Num weight bits = 29
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# creating cache_file = train_v.cache
# Reading datafile =
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0  -1.0000   0.0000     4173
# 0.500000 0.000000            2            2.0  -1.0000  -1.0000     2273
# 0.250000 0.000000            4            4.0  -1.0000  -1.0000     2241
# 0.866891 1.483782            8            8.0  -1.0000  -0.1026     3006
# 1.290152 1.713413           16           16.0   1.0000   1.0000     6257
# 1.184900 1.079648           32           32.0   1.0000   1.0000     2530
# 0.933104 0.681308           64           64.0   1.0000   1.0000     4209
# 0.657120 0.381136          128          128.0   1.0000   0.8641     3299
# 0.474147 0.291175          256          256.0   1.0000   1.0000     4314
# 0.365200 0.256252          512          512.0   1.0000   0.2557     5159
# 0.273049 0.180898         1024         1024.0  -1.0000  -1.0000     1825
# 0.213867 0.154685         2048         2048.0  -1.0000  -0.8447     8785
# 0.181079 0.148291         4096         4096.0   1.0000   1.0000     7304
# 0.143920 0.106761         8192         8192.0   1.0000   1.0000     3143
# 0.113692 0.083463        16384        16384.0   1.0000   1.0000     6925
# 0.091925 0.070158        32768        32768.0   1.0000   1.0000     5262
# 0.072055 0.052186        65536        65536.0   1.0000   1.0000     7712
# 0.055181 0.038307       131072       131072.0  -1.0000  -1.0000     3001
# 0.042012 0.028843       262144       262144.0  -1.0000  -1.0000     4288
#
# finished run
# number of examples = 280130
# weighted example sum = 280130.000000
# weighted label sum = 59668.000000
# average loss = 0.040979
# best constant = 0.213001
# best constant's loss = 0.954631
# total feature number = 1045000907

# %%
# !python phraug/libsvm2vw.py test_v.txt /dev/stdout \
| vw -b 29 --cache_file test_v.cache
# Out:
# Num weight bits = 29
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# creating cache_file = test_v.cache
# Reading datafile =
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0  -1.0000   0.0000     1962
# 0.500002 0.000004            2            2.0  -1.0000  -0.9980     3854
# 1.073507 1.647012            4            4.0   1.0000  -0.8149     2560
# 0.809621 0.545736            8            8.0  -1.0000  -1.0000     4521
# 1.125993 1.442365           16           16.0   1.0000   1.0000     3004
# 0.926786 0.727578           32           32.0   1.0000   0.5664     4647
# 0.633341 0.339895           64           64.0   1.0000   1.0000     4331
# 0.572883 0.512425          128          128.0   1.0000   1.0000     4723
# 0.414914 0.256945          256          256.0   1.0000  -0.0028      943
# 0.358294 0.301673          512          512.0   1.0000   1.0000     1643
# 0.262811 0.167328         1024         1024.0  -1.0000  -1.0000     4387
# 0.212473 0.162135         2048         2048.0   1.0000   1.0000     4210
# 0.162758 0.113043         4096         4096.0  -1.0000  -1.0000     2107
# 0.129817 0.096876         8192         8192.0   1.0000   1.0000     3498
# 0.103784 0.077751        16384        16384.0   1.0000   1.0000     6102
# 0.084343 0.064903        32768        32768.0  -1.0000  -1.0000     3601
# 0.066728 0.049113        65536        65536.0  -1.0000  -0.4692     1555
#
# finished run
# number of examples = 69870
# weighted example sum = 69870.000000
# weighted label sum = 14710.000000
# average loss = 0.065017
# best constant = 0.210534
# best constant's loss = 0.955675
# total feature number = 260046539

# %% [markdown]
# ### Запускаем обучение

# %% [markdown]
# Поддерживаемые функционалы (--loss_function):
#
# * squared 1/2(y-a(x))^2
# * classic - quadratic без взвешивания весов
# * quantile \tau(a(x)-y)[y \leqslant a(x)]+(1-\tau)(y-a(x))[y \geqslant a(x)]
# * logistic log(1 + exp (-ya(x)))
# * hinge max(0,1 - ya (x))

# %% [markdown]
# Можно так же добваить регуляризацию:
# * --l1 value
# * --l2 value

# %%
# !vw --cache_file train_v.cache --loss_function logistic -b 29 -P 10000 --passes 10
# Out:
# Num weight bits = 29
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = train_v.cache
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.150932 0.150932        10000        10000.0   1.0000   9.3851     3702
# 0.126585 0.102238        20000        20000.0   1.0000   7.7036     4373
# 0.114448 0.090173        30000        30000.0  -1.0000  -5.2946     1346
# 0.108335 0.089996        40000        40000.0  -1.0000  -5.7050      117
# 0.103104 0.082181        50000        50000.0   1.0000  10.4773     2886
# 0.098748 0.076965        60000        60000.0  -1.0000  -2.9820      668
# 0.094184 0.066802        70000        70000.0   1.0000   7.5152     2739
# 0.089475 0.056509        80000        80000.0   1.0000  12.6887     3592
# 0.086110 0.059192        90000        90000.0  -1.0000  -7.6076     2184
# 0.081995 0.044961       100000       100000.0  -1.0000  -1.6523     5866
# 0.080773 0.068554       110000       110000.0   1.0000  11.8876     5098
# 0.077945 0.046837       120000       120000.0  -1.0000  -7.6050     2106
# 0.074947 0.038969       130000       130000.0   1.0000   8.1351     8121
# 0.073659 0.056923       140000       140000.0   1.0000  12.5861     6260
# 0.070899 0.032246       150000       150000.0  -1.0000  -1.7580     2253
# 0.069311 0.045496       160000       160000.0  -1.0000  -5.4537     3239
# 0.068275 0.051709       170000       170000.0  -1.0000  -7.6502      330
# 0.042165 0.014900      1060000      1060000.0   1.0000  19.3485     4691 h
# 0.041898 0.013588      1070000      1070000.0  -1.0000 -15.0180      214 h
# 0.041853 0.037023      1080000      1080000.0   1.0000   7.9168     1057 h
# 0.041643 0.019009      1090000      1090000.0   1.0000  11.0452     7637 h
# 0.041381 0.012816      1100000      1100000.0   1.0000  10.3532     5813 h
# 0.041293 0.031553      1110000      1110000.0   1.0000  15.0039     4431 h
# 0.041673 0.083899      1120000      1120000.0  -1.0000  -8.4450      259 h
# 0.042145 0.094979      1130000      1130000.0   1.0000   3.5971     2707 h
# 0.041989 0.024383      1140000      1140000.0   1.0000  18.7273     3596 h
# 0.042370 0.085791      1150000      1150000.0   1.0000  11.5160     5792 h
# 0.042187 0.021112      1160000      1160000.0   1.0000  14.6803     2786 h
# 0.042420 0.069491      1170000      1170000.0   1.0000   8.2518     1886 h
# 0.042415 0.041820      1180000      1180000.0  -1.0000 -14.9276     4418 h
# 0.042213 0.018383      1190000      1190000.0  -1.0000  -7.2060     1827 h
# 0.042074 0.025500      1200000      1200000.0  -1.0000 -43.1321     4279 h
# 0.042537 0.098075      1210000      1210000.0  -1.0000  -8.2752     4381 h
# 0.042462 0.033486      1220000      1220000.0  -1.0000  -7.6812     5811 h
# 0.042299 0.022335      1230000      1230000.0   1.0000  13.4283    10802 h
# 0.042095 0.017032      1240000      1240000.0   1.0000  14.0669     3273 h
# 0.042257 0.062296      1250000      1250000.0   1.0000  11.6266     5766 h
# 0.042052 0.016489      1260000      1260000.0  -1.0000  -9.1380     2251 h
#
# finished run
# number of examples per pass = 252117
# passes used = 5
# weighted example sum = 1260585.000000
# weighted label sum = 267715.000000
# average loss = 0.034177 h
# best constant = 0.431312
# best constant's loss = 0.670423
# total feature number = 4703089205

# %% [markdown]
# Параметр отвечающий, за наличие валидационного датасета
# * --holdout_off

# %%
# !vw --cache_file train_v.cache --loss_function logistic -b 29 -P 10000 --passes 5 --holdout_off -f model_v_logistic
# Out:
# final_regressor = model_v_logistic
# Num weight bits = 29
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = train_v.cache
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.151009 0.151009        10000        10000.0   1.0000  12.1563     4848
# 0.128242 0.105475        20000        20000.0   1.0000  10.6945     5341
# 0.113506 0.084035        30000        30000.0   1.0000  12.5036     4536
# 0.103489 0.073437        40000        40000.0   1.0000   4.2872     6491
# 0.100947 0.090780        50000        50000.0  -1.0000 -10.1950      258
# 0.095359 0.067417        60000        60000.0  -1.0000  -2.4623      690
# 0.092400 0.074649        70000        70000.0  -1.0000  -6.4080     2107
# 0.088415 0.060522        80000        80000.0   1.0000   7.6411     3660
# 0.083498 0.044159        90000        90000.0  -1.0000 -12.2838     1006
# 0.080554 0.054055       100000       100000.0   1.0000  12.1350     3950
# 0.076812 0.039401       110000       110000.0  -1.0000  -7.0715      245
# 0.075121 0.056517       120000       120000.0   1.0000  13.0818     6981
# 0.074076 0.061538       130000       130000.0  -1.0000  -7.4960     2206
# 0.071282 0.034949       140000       140000.0   1.0000  13.0458     6089
# 0.069266 0.041050       150000       150000.0  -1.0000  -2.6819     7117
# 0.067851 0.046624       160000       160000.0   1.0000   1.5482     8480
# 0.021365 0.008450      1090000      1090000.0   1.0000  17.7296     6107
# 0.021229 0.006378      1100000      1100000.0   1.0000  12.0514     5898
# 0.021094 0.006255      1110000      1110000.0   1.0000  17.3003     4500
# 0.020959 0.006029      1120000      1120000.0   1.0000  20.6770     4504
# 0.020836 0.007019      1130000      1130000.0   1.0000  19.8030     4942
# 0.020705 0.005894      1140000      1140000.0   1.0000  18.8370     5609
# 0.020579 0.006276      1150000      1150000.0  -1.0000 -10.5862      795
# 0.020448 0.005372      1160000      1160000.0  -1.0000  -5.9244     4493
# 0.020319 0.005376      1170000      1170000.0  -1.0000  -8.7229      916
# 0.020190 0.005051      1180000      1180000.0  -1.0000 -10.8376      615
# 0.020064 0.005180      1190000      1190000.0   1.0000  17.8641     1086
# 0.019951 0.006467      1200000      1200000.0   1.0000  16.8653     5387
# 0.019832 0.005592      1210000      1210000.0   1.0000  28.5091     5572
# 0.019704 0.004267      1220000      1220000.0  -1.0000  -7.1860      164
# 0.019582 0.004699      1230000      1230000.0  -1.0000  -6.4855     4234
# 0.019475 0.006298      1240000      1240000.0  -1.0000 -11.0460     3890
# 0.019365 0.005754      1250000      1250000.0   1.0000  12.2226     2980
# 0.019255 0.005497      1260000      1260000.0  -1.0000  -6.2536     4287
# 0.019137 0.004231      1270000      1270000.0   1.0000   5.4201      354
# 0.019026 0.004913      1280000      1280000.0  -1.0000 -14.3984      293
# 0.018911 0.004252      1290000      1290000.0   1.0000  11.2436     5688
# 0.018798 0.004161      1300000      1300000.0   1.0000  18.8622     5665
# 0.018700 0.005990      1310000      1310000.0   1.0000  12.7493     5469
# 0.018599 0.005330      1320000      1320000.0   1.0000  22.3127     4038
# 0.018498 0.005163      1330000      1330000.0   1.0000  19.2008     4425
# 0.018398 0.005053      1340000      1340000.0  -1.0000 -11.2091     2338
# 0.018301 0.005389      1350000      1350000.0  -1.0000 -10.0998     2257
# 0.018216 0.006781      1360000      1360000.0   1.0000   9.8047     5988
# 0.018138 0.007413      1370000      1370000.0   1.0000  24.2675     1256
# 0.018043 0.005017      1380000      1380000.0   1.0000  -0.3803     8610
# 0.017951 0.005332      1390000      1390000.0   1.0000  12.6191     6707
# 0.017860 0.005185      1400000      1400000.0  -1.0000  -7.6642     1220
#
# finished run
# number of examples per pass = 280130
# passes used = 5
# weighted example sum = 1400650.000000
# weighted label sum = 298340.000000
# average loss = 0.017854
# best constant = 0.432626
# best constant's loss = 0.670288
# total feature number = 5225004535

# %%
# !vw --cache_file test_v.cache -i model_v_logistic -t -p preds.txt
# Out:
# only testing
# predictions = preds.txt
# Num weight bits = 29
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = test_v.cache
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 5.443122 5.443122            1            1.0  -1.0000  -3.3331     1962
# 31.637787 57.832451            2            2.0  -1.0000  -8.6048     3854
# 90.605680 149.573574            4            4.0   1.0000  11.6048     2560
# 177.015556 263.425431            8            8.0  -1.0000 -30.1791     4521
# 190.556256 204.096956           16           16.0   1.0000  19.7413     3004
# 222.444949 254.333641           32           32.0   1.0000  15.1369     4647
# 221.359732 220.274515           64           64.0   1.0000  19.2997     4331
# 197.487441 173.615151          128          128.0   1.0000  17.3244     4723
# 204.039426 210.591412          256          256.0   1.0000   4.0830      943
# 199.761520 195.483614          512          512.0   1.0000  16.6381     1643
# 203.486146 207.210772         1024         1024.0  -1.0000 -32.5306     4387
# 207.811243 212.136340         2048         2048.0   1.0000  21.4800     4210
# 211.209579 214.607916         4096         4096.0  -1.0000 -10.2791     2107
# 209.775433 208.341287         8192         8192.0   1.0000  21.8786     3498
# 210.934161 212.092889        16384        16384.0   1.0000  17.4804     6102
# 212.315304 213.696446        32768        32768.0  -1.0000 -11.3895     3601
# 211.207981 210.100658        65536        65536.0  -1.0000  -3.6421     1555
#
# finished run
# number of examples = 69870
# weighted example sum = 69870.000000
# weighted label sum = 14710.000000
# average loss = 211.056747
# best constant = 0.210534
# best constant's loss = 0.955675
# total feature number = 260046539

# %% [markdown]
# Вычислим метрики:

# %%
import sys
import numpy as np
from sklearn.metrics import accuracy_score as accuracy
from sklearn.metrics import roc_auc_score as AUC
from sklearn.metrics import confusion_matrix

y_file = "test_v.txt"
p_file = "preds.txt"

print "loading p..."

p = np.loadtxt( p_file )

y_predicted = np.ones(( p.shape[0] ))
y_predicted[p < 0] = -1

print "loading y..."

y = np.loadtxt( y_file, usecols= [0] )

print "accuracy:", accuracy( y, y_predicted )
print "AUC:", AUC( y, p )

print
print "confusion matrix:"
print confusion_matrix( y, y_predicted )
# Out:
# loading p...
# loading y...
# accuracy: 0.9946758265349935
# AUC: 0.9984184361202244
#
# confusion matrix:
# [[27444   136]
#  [  236 42054]]

# %% [markdown]
# Дополнительные параметры:
# * -q AB -- Добавляет все парные признаки, где первый признак берется из Namespace A, а второй из Namespace B
# * --cubic ABC -- Аналогично с тройками признаков
# * --ngram AN -- генерирует n-граммы для пространста A
# * --skips AK -- позволяет делать пропуски длины k в n-граммах простанств A

# %% [markdown]
# Автоматический подбор гиперпараметров можно делать через
# **vw-hyperopt**

# %% [markdown]
# ### Анализ модели

# %% [markdown]
# * --readable_model позволяет получить модель, в человеко-читаемом формате
# * --invert_hash не умеет работать с кешем, но выдает поятные имена фичей, вместо номеров
# * --audit_regressor позволяет получить описание модели с использованными фичами, однако требует повторного запуска.

# %%
! vw -d test.vw -t -i small_model.vw --audit_regressor audit_regr
# Out:
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using no cache
# Reading datafile = test.vw
# num sources = 1
# Regressor contains 8685 values
# example      values         total
# counter      audited        progress
# 1                  300            3%
# 2                  324            3%
# 4                  352            4%
# 8                  369            4%
# 16                 471            5%
# 32                 690            7%
# 64                1060           12%
# 128               1246           14%
# 256               2265           26%
# 512               2780           32%
# 1024              4056           46%
# 2048              4774           54%
# 4096              5919           68%
# 7032              8685          100%

# %%
features = {}
with open ("audit_regr", "r") as audit:
    for l in audit:
        features[l.split (':')[0][5:]] = float(l.split (':')[2].strip ())

# %%
list (reversed (sorted(features, key=features.get)))
# Out:
# ['ant',
#  'rss',
#  'email',
#  'shy',
#  'vip',
#  'xml',
#  '3jp',
#  'narod',
#  '0px',
#  'steam',
#  'notes',
#  'imei',
#  'netfirms',
#  '1584',
#  'eajaq',
#  'torrent',
#  'guest',
#  'message',
#  '376',
#  'hotel',
#  'tokio',
#  'tristar',
#  'milaya',
#  'telefonnummer',
#  'h2o',
#  'copyright',
#  'bmw',
#  'hmsite',
#  'domrabota',
#  'autocad',
#  'mop',
#  'mdash',
#  'published',
#  'spb',
#  '115',
#  '143',
#  '624',
#  '644',
#  'mot',
#  '969ae6',
#  '1987',
#  'pronoun',
#  'qip',
#  '443',
#  'admin',
#  'mail',
#  'net',
#  'elit',
#  'ins',
#  'prostitutki',
#  '2498',
#  'tyumile',
#  'antikombatz',
#  'sisnbro',
#  '1945',
#  '377',
#  'xtreemhost',
#  'froebie',
#  'waited',
#  'acontario',
#  'gidsupatscat',
#  '5000',
#  'appendchild',
#  'design',
#  'zona',
#  '611',
#  '116',
#  '2125',
#  'names',
#  'ftp',
#  '520',
#  'ecce',
#  '619',
#  '184',
#  '164',
#  'padding',
#  'edu',
#  'lurkmore',
#  'tcgkfnyj',
#  '480',
#  'novruslit',
#  'incredimail',
#  'nnn',
#  'backup',
#  'hosting',
#  '2242px',
#  '322',
#  'anh',
#  'fmneniewe',
#  'ngerverkaufen',
#  'studentenrevolte',
#  'besitzergreifung',
#  'leben',
#  'rinderroulade',
#  'fuers',
#  '1810',
#  'xxx',
#  'domain',
#  '1933',
#  '478',
#  'rveowaem',
#  'ciwoci',
#  'chez',
#  'mobico',
#  'desperadoes',
#  'sergen',
#  '33829',
#  'gebrauchtwagen',
#  'iterationsverfahren',
#  'ndler',
#  'dreformagl',
#  '458',
#  'static',
#  'svetlana',
#  '667',
#  'golgvin',
#  '1978',
#  '351',
#  'bvty',
#  '0353',
#  'crm',
#  '536',
#  '352',
#  '870',
#  '537',
#  '4rccdser',
#  'rccdplus',
#  '354',
#  'bunny',
#  'loveplanet',
#  'anna',
#  'maisie',
#  '823',
#  '1545',
#  '288',
#  '389',
#  'multyplayer',
#  'berweisungen',
#  'schwerlaster',
#  'wenig',
#  'singls',
#  'photo2vcd',
#  'geld',
#  'hanna',
#  'technik',
#  '538',
#  '676',
#  'hyrveajr',
#  'ultra',
#  '371',
#  'monkey',
#  'koolmoves',
#  'lucky',
#  'comedy',
#  'uni',
#  '604',
#  '540',
#  '407',
#  'pofig',
#  'klas',
#  'valentina',
#  'heuransirec',
#  'transformers',
#  'web',
#  '0701',
#  'power',
#  '626',
#  'gps',
#  '618',
#  '9955599',
#  '756',
#  'sex',
#  '137',
#  'xix',
#  'designs',
#  'mercedez',
#  'nina',
#  'narod2',
#  '622',
#  '623',
#  'homo',
#  'teasernet',
#  '1822330',
#  '586',
#  '1free',
#  '7cfdadba',
#  'encodyd',
#  'remn',
#  '4452409',
#  '462',
#  'answerdiv',
#  'commentfield',
#  '168',
#  'will',
#  'eigenhead',
#  'eigenmath',
#  '426',
#  'february',
#  'macro',
#  'cntscr',
#  '484',
#  '141',
#  '11px',
#  'xviii',
#  'ero',
#  '310',
#  '297',
#  'tahoma',
#  '441',
#  '309',
#  '109',
#  '279',
#  '1917',
#  '3539',
#  '215',
#  'gay',
#  '355',
#  'irvono',
#  'ubuntu',
#  'map',
#  'dosug',
#  'gta',
#  '320',
#  'build',
#  '447',
#  'joomla',
#  'che',
#  '413',
#  '496',
#  '169',
#  '256',
#  'nvidia',
#  '304',
#  '165',
#  'vst',
#  'xcition',
#  'motion',
#  'thule',
#  'ultima',
#  'cosmos',
#  'v2004',
#  '3gp',
#  '308',
#  '1854',
#  'wsw',
#  'security',
#  'ten',
#  'internationale',
#  'organisation',
#  'beitrag',
#  'gesellschaft',
#  'spezialit',
#  'bau',
#  'rente',
#  'europ',
#  'ische',
#  'rme',
#  '2414542191173168',
#  '7702593320',
#  'mcp77',
#  'submitp',
#  'art',
#  '1n1',
#  'joomsef',
#  'switchoffautohideshow',
#  '272',
#  'october',
#  'add',
#  'download',
#  '961',
#  '3411',
#  'elnur',
#  'diwuroy',
#  'guneshli',
#  'oni',
#  '274',
#  '158',
#  'brush',
#  'examination',
#  'dr5050',
#  '30000',
#  'usoirpde',
#  '2500',
#  '1141',
#  '1140',
#  '1142',
#  'beausset',
#  '1135',
#  '1137',
#  '1138',
#  '1139',
#  'launce7fzhanel',
#  'mpeg',
#  '1136',
#  'xvi',
#  '140',
#  'sitemap',
#  'w83627',
#  'i845g',
#  'c8c7b8',
#  '232',
#  '145',
#  '645',
#  '440',
#  'producer',
#  '646',
#  'blockid',
#  'padid',
#  'example',
#  'partner',
#  '170',
#  'sugar',
#  'robotronic',
#  'bytes',
#  '1942',
#  'related',
#  'flashumor',
#  '642',
#  'grcffvw9y14bshgfsqmewezks0e',
#  '24open',
#  '337',
#  '7000',
#  'not',
#  '620',
#  '621',
#  '182',
#  'seo',
#  '1143',
#  '897',
#  '895',
#  '894',
#  '892',
#  'erodtipho',
#  'generals',
#  '896',
#  '893',
#  '889',
#  'recorder',
#  '366',
#  '1970',
#  'cat',
#  '454',
#  'sriemn',
#  'bosses',
#  'turbo3',
#  'busty',
#  'lupe',
#  'angelica',
#  '335',
#  '444',
#  'rus',
#  'little',
#  '594',
#  'elkin',
#  'ablakim',
#  'mitrofan',
#  'dmitrij',
#  'garishvili',
#  'asyja',
#  'belolovets',
#  'kirkija',
#  'kornkjchuk',
#  'smyslov',
#  '334',
#  'neofon',
#  'xpress',
#  '1245',
#  '1898',
#  '708',
#  'index',
#  'pprlon',
#  '1792',
#  '1938',
#  '273',
#  '492',
#  '639',
#  'shareaholic',
#  '0325',
#  'white',
#  '20080511',
#  'zorinbox',
#  'dictate',
#  'mifocm',
#  'wlu',
#  'style2',
#  'ff00ff',
#  'megabyet',
#  'express',
#  '704',
#  '1789',
#  '114',
#  'tbtype',
#  '2013',
#  '2014',
#  '2015',
#  '186',
#  '7uw',
#  'cpanel',
#  'irc',
#  '1924',
#  'main',
#  'ereev',
#  '190',
#  'gallery',
#  '1843',
#  '489',
#  '142',
#  '891',
#  '647',
#  '188',
#  '452',
#  '459',
#  'ati',
#  'warenprobenverteilung',
#  'gebraucht',
#  'probetest',
#  'akdettai',
#  'buch',
#  'archive',
#  '33699',
#  'degressive',
#  'abschreibung',
#  '0349',
#  '456',
#  '378',
#  '451',
#  '144',
#  'serdechko2',
#  '1589',
#  'namo',
#  '658',
#  'ffe0ee',
#  '677',
#  'iucet',
#  '552',
#  '455',
#  'encodeuricomponent',
#  '73273',
#  '670',
#  '751',
#  '752',
#  '749',
#  'edicrv',
#  'plus',
#  '307',
#  '183',
#  't44',
#  '2004',
#  'tegos',
#  'ft17',
#  'edda',
#  '402',
#  '477',
#  '464',
#  'tass',
#  'tonetown',
#  'website',
#  'studio',
#  'love',
#  'f5e2b1',
#  '497',
#  '442',
#  'elite',
#  'grand',
#  '445',
#  '408',
#  '88213',
#  'sboj',
#  'oneanime',
#  'parameter',
#  'afom',
#  'toprstoj',
#  'oas',
#  '403',
#  'valid',
#  'project',
#  'org',
#  'radeon',
#  '1948',
#  'bdsm',
#  '542',
#  '1981',
#  '409',
#  '118',
#  'says',
#  'january',
#  '2114',
#  'gifimg',
#  'background',
#  'loadtab',
#  '218',
#  '1743',
#  'vult',
#  '1695',
#  'aldebaran',
#  '1793',
#  'deus',
#  '4413',
#  'parvissimus',
#  'quos',
#  '1766',
#  '333',
#  'required',
#  'fpth',
#  'fyt',
#  'fql',
#  '530',
#  'porno',
#  '2132',
#  'salamutzforum',
#  '394',
#  'xpcspy',
#  '453',
#  'sms',
#  'res',
#  '1875',
#  'hachimangu',
#  'puta',
#  'wakamiya',
#  '191',
#  '460',
#  'sds2',
#  '678',
#  'treiwr',
#  '643',
#  '185',
#  'tecktonik',
#  'chlen',
#  'krupnim',
#  'planom',
#  'twitter',
#  '336',
#  '222796',
#  'captions',
#  '222792',
#  'adorama',
#  'sader',
#  '615',
#  '614',
#  '613',
#  '303',
#  'pages',
#  'fontana',
#  'oslik',
#  'isabeli',
#  'rnb',
#  'invisible',
#  '200',
#  '1936',
#  'zend',
#  'toni',
#  'pets',
#  '243',
#  '784',
#  '63523',
#  'beta',
#  'hyena',
#  'ocean',
#  'ccna',
#  'cyklotrasy',
#  'watch',
#  'install',
#  'calamity',
#  'entfernt',
#  'buchwalter',
#  'blazblue',
#  'trigger',
#  'mind',
#  'bei',
#  'timelimit',
#  'desktop',
#  'routersim',
#  'powerzip',
#  'atlantis',
#  'onlayin',
#  'psp7',
#  'tuneup',
#  'mailwasher',
#  'dna',
#  'easy',
#  'reserved',
#  'understand',
#  'contacts',
#  'dvd',
#  'free',
#  'follow',
#  '1925',
#  'reply',
#  'stumbleupon',
#  'responses',
#  'digg',
#  '1895',
#  'inna1983',
#  'read',
#  '172',
#  'parentnode',
#  'leofetch',
#  'ls50a',
#  'crack',
#  'converter',
#  '509',
#  'creator',
#  'rights',
#  'odnoklassniki',
#  'intpl',
#  'comment',
#  '331',
#  'icq',
#  'alizee',
#  'deluxe',
#  'webeditor',
#  'keygen',
#  'elena',
#  '821b47c1',
#  '6277603',
#  'banner2',
#  'keyword',
#  '608',
#  'gff',
#  'kato',
#  '510',
#  'theme',
#  'facebook',
#  'gasvent',
#  'mac',
#  '151',
#  'overflow',
#  'files',
#  'menu',
#  'get',
#  'leave',
#  'linux',
#  'best',
#  'macromedia',
#  'x64',
#  '439741',
#  'eps',
#  'powerlifting',
#  'boyfriend',
#  '630048',
#  'siteheart',
#  'award',
#  'slando',
#  'vworld',
#  'referer',
#  '390',
#  'jessica',
#  'december',
#  'bdg',
#  'wiki',
#  'ffeef2',
#  'more',
#  'pornoand',
#  '3950986',
#  'affordable',
#  'about',
#  'greh',
#  '446',
#  'partition',
#  'netzleisten',
#  'bauprogramm',
#  'sung',
#  'ller',
#  'v11',
#  'oggidata',
#  'v2003',
#  'mattm',
#  'fairies',
#  'engergiekosten',
#  'aufl',
#  'hohe',
#  'sowietunion',
#  'redvase',
#  'suite',
#  'lycos',
#  'angelfire',
#  'online',
#  'wallchanger',
#  'crusader',
#  'seawolves',
#  'corners',
#  'hunt',
#  'equifile',
#  'cls',
#  'stronghold',
#  'personalzeit',
#  '10c',
#  'aqua',
#  'hobbit',
#  'milestones',
#  'kutinsoft',
#  'termin',
#  'authorware',
#  'submarines',
#  'nature',
#  'cacheman',
#  '189',
#  '917',
#  'ole5055',
#  'abejitam',
#  'mit',
#  'koten619',
#  'marina5588',
#  'tasy',
#  'gipups',
#  'maxverona',
#  'dem',
#  'vilenia',
#  'lastochkin',
#  'ekirilkin',
#  'olga',
#  'safonov16',
#  'step',
#  'gribk',
#  '224367',
#  'yeah',
#  'tes11',
#  'forces',
#  'alexeevairina',
#  'arsentia',
#  'natafz',
#  'sperma',
#  'pornografia',
#  'tatyana2008',
#  'her',
#  'evgeniy',
#  'karamsin',
#  'aksal9',
#  'h4alth',
#  'nika555nika',
#  'sytina',
#  'svcd',
#  'vcd',
#  'zealot',
#  'utm',
#  'novost',
#  'famfamfam',
#  'thread',
#  'juliusex',
#  'nabor',
#  '910',
#  'network',
#  'ipod',
#  '3th',
#  '1628',
#  'harlampiybelikova826',
#  'gzxrscrvlo4eldjit',
#  '2540319',
#  '0njf',
#  'guanfxqr4nzdc8wnj',
#  'ft46',
#  '1100',
#  'aobj',
#  'lockngo',
#  'wave',
#  'maker',
#  'logitech',
#  'organizer',
#  '241',
#  'city',
#  '12px',
#  'otic',
#  '387',
#  'french',
#  'yahhy',
#  'heroes',
#  'sonic',
#  '211',
#  'atlon',
#  '82801g',
#  'wow',
#  'miaozi',
#  'jar',
#  'ich7',
#  'high',
#  'definition',
#  'technology',
#  'x1600',
#  '222',
#  'uhpm',
#  'gocope',
#  'squ',
#  'club',
#  'metaproducts',
#  'enterprise',
#  'json22284',
#  'hjnbxtcrbt',
#  'r15',
#  'autogasinstallation',
#  'json1608',
#  'mieten',
#  'rebeca',
#  'widerrufsrecht',
#  'sportfahrertraining',
#  'tte',
#  'strike',
#  '457',
#  'audio',
#  '641',
#  'asus',
#  'aetoreir',
#  'contact',
#  'edition',
#  'ybo',
#  'emoanv',
#  'bakir',
#  'templates',
#  'cart',
#  '808',
#  'back',
#  'trial',
#  '718',
#  '548',
#  'eomeiwr',
#  '847',
#  '693',
#  'alkogol',
#  'elisaveta',
#  'cookieval',
#  'service',
#  'epson',
#  '1292',
#  '1334',
#  '499',
#  'jumpover',
#  'faction',
#  'shredder',
#  '213',
#  'winx',
#  'top',
#  '7343469249',
#  '2632557032795503',
#  '1302',
#  'kup9yyiv9cfof',
#  '965',
#  'kod',
#  'rsl',
#  '007',
#  '742',
#  '954',
#  'rns',
#  'sitepage',
#  'triple',
#  'kilu',
#  '195272',
#  'popel',
#  'getelementsbytagname',
#  '580',
#  'bukvar',
#  'eguxaleq',
#  'falscher',
#  'igor',
#  'korchak',
#  'mastercard',
#  'tarifberechnung',
#  'malta',
#  'vcemirna',
#  'vallav',
#  'day',
#  'checklisten24',
#  'artur2011',
#  'mgts239414',
#  'freund',
#  'blagov58',
#  'comte',
#  'galias',
#  'astrologie',
#  'rednev',
#  'zabava',
#  'institut',
#  'month',
#  'mont',
#  'adamcevich',
#  'psychologische',
#  'valentyna',
#  'vertrag',
#  'composernesteroff',
#  'ludmila',
#  'sydney7',
#  'plam',
#  'fill16862',
#  'uebernehmen',
#  'pagez',
#  'tlipatova5',
#  'gizywa',
#  'forge2006',
#  'mumiya20091',
#  '2303',
#  'miller',
#  'skype',
#  'json9820',
#  'modelle',
#  'muskelst',
#  'altert',
#  'desperotegaze',
#  'auxa',
#  'mer',
#  'json25789',
#  'titans',
#  'melodiatur',
#  'rkung',
#  'knigge',
#  'bauen',
#  'gfi',
#  'icons',
#  'popslot',
#  'eventtag',
#  '203',
#  'quickeys',
#  '3177',
#  'travianbot',
#  'ka4ka',
#  'ispmanager',
#  'cs3',
#  'smsdelivery',
#  'guide',
#  'autozmc',
#  'nero',
#  'fireshot',
#  'oberon',
#  'antivirus',
#  'kulinar4',
#  'chessimo',
#  'doktorweb',
#  'winc',
#  'manager',
#  'scrollmessage',
#  'daviddolgorukova187',
#  'dimazan',
#  'blogdog',
#  'bilingual',
#  '347',
#  'scripts',
#  'feurio',
#  'cnc2004',
#  'rental',
#  'finest',
#  'jf7',
#  'tracker',
#  'circuitmaker200trial',
#  'bootmanager',
#  'solsuite',
#  'voiceon',
#  'fotoworks',
#  'livestock',
#  '744',
#  'property',
#  'customer',
#  'zonelabs',
#  'cloner',
#  'zonealarm',
#  'netsupport',
#  'bootstar',
#  'swf',
#  'allnews',
#  '3em',
#  'listpos',
#  'webmail',
#  'grouper',
#  '372b',
#  'notify',
#  'cyber',
#  '2994',
#  'restoration',
#  'batchrename',
#  'cleanup',
#  'bluewave',
#  'jpgavi',
#  'codesmith',
#  'opti',
#  'qsync',
#  'windvd',
#  'zip',
#  'solus',
#  'offline',
#  'clock',
#  'moony',
#  'pcstitch',
#  'wordsheets',
#  'acer',
#  '3490',
#  'criteria',
#  'xfn',
#  'mip',
#  'designed',
#  'sorry',
#  'matched',
#  'caterpillar',
#  '6957281794',
#  'utnmed',
#  '2406580529785234',
#  'flash',
#  'july',
#  'alizfe',
#  'minibb',
#  'alizzee',
#  'simpson',
#  '801',
#  'iuqaket',
#  '0359',
#  ...]

# %% [markdown]
# ### Дополнительные параметры

# %% [markdown]
# * --progressive_loss прежде, чем пересчитать коэффициенты для текущего семпла, вычисляет для него функцию потерь. При множественных прохождениях теряет смысл.
# * --bs позволяет использовать boostrapping

# %% [markdown]
# ### Сcылки

# %% [markdown]
# https://habr.com/ru/company/ods/blog/326418/
#
# http://fastml.com/vowpal-wabbit-liblinear-sbm-and-streamsvm-compared/
#
# про значение весов: https://arxiv.org/abs/1011.1576
#
# как сделан бустреп: https://arxiv.org/abs/1312.5021
